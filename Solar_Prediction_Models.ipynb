# %% [markdown]
# Simple Neural Network

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LeakyReLU
from tensorflow.keras.callbacks import EarlyStopping

data_combined = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915, 4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845, 5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194, 7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567, 11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991, 13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768, 16740, 30080, 27120, 25200, 26480],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216, 11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580, 10080, 12120, 15500, 14220, 16040],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072, 10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960, 5140, 11840, 15680, 14460, 15900]
}

def create_dataset(data, window_size=3):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

X_p2, y_p2 = create_dataset(data_combined["Tower 2"], window_size=3)

scaler_X = MinMaxScaler()
X_p2_scaled = scaler_X.fit_transform(X_p2)

y_p2 = y_p2.reshape(-1, 1)
scaler_y = MinMaxScaler()
y_p2_scaled = scaler_y.fit_transform(y_p2)

X_train, X_test, y_train, y_test = train_test_split(X_p2_scaled, y_p2_scaled, test_size=0.2, random_state=42)

# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    LeakyReLU(alpha=0.01),
    Dense(64),
    LeakyReLU(alpha=0.01),
    Dense(32),
    LeakyReLU(alpha=0.01),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])

test_loss = model.evaluate(X_test, y_test)

predictions = model.predict(X_test)

predictions = scaler_y.inverse_transform(predictions)

print("Test Loss:", test_loss)
print("Predictions:", predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/activations/leaky_relu.py:41: UserWarning: Argument `alpha` is deprecated. Use `negative_slope` instead.
#   warnings.warn(
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step - loss: 0.2890 - val_loss: 0.2218
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.2128 - val_loss: 0.1674
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step - loss: 0.1522 - val_loss: 0.1254
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.1057 - val_loss: 0.0971
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.0733 - val_loss: 0.0802
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0553 - val_loss: 0.0755
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0501 - val_loss: 0.0784
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0550 - val_loss: 0.0839
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step - loss: 0.0638 - val_loss: 0.0884
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - loss: 0.0713 - val_loss: 0.0897
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step - loss: 0.0749 - val_loss: 0.0883
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0742 - val_loss: 0.0844
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step - loss: 0.0700 - val_loss: 0.0793
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - loss: 0.0645 - val_loss: 0.0751
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - loss: 0.0588 - val_loss: 0.0715
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step - loss: 0.0536 - val_loss: 0.0688
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step - loss: 0.0494 - val_loss: 0.0672
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - loss: 0.0465 - val_loss: 0.0666
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - loss: 0.0448 - val_loss: 0.0670
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - loss: 0.0441 - val_loss: 0.0676
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step - loss: 0.0442 - val_loss: 0.0680
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step - loss: 0.0445 - val_loss: 0.0677
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 612ms/step - loss: 0.0448 - val_loss: 0.0668
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - loss: 0.0446 - val_loss: 0.0651
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0440 - val_loss: 0.0628
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0428 - val_loss: 0.0601
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0413 - val_loss: 0.0570
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.0397 - val_loss: 0.0540
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0382 - val_loss: 0.0513
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0370 - val_loss: 0.0490
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0361 - val_loss: 0.0472
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0357 - val_loss: 0.0460
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.0354 - val_loss: 0.0449
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step - loss: 0.0351 - val_loss: 0.0438
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0347 - val_loss: 0.0426
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0340 - val_loss: 0.0412
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0331 - val_loss: 0.0402
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step - loss: 0.0320 - val_loss: 0.0393
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - loss: 0.0310 - val_loss: 0.0386
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0301 - val_loss: 0.0380
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0293 - val_loss: 0.0374
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 0.0288 - val_loss: 0.0368
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0284 - val_loss: 0.0360
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0279 - val_loss: 0.0350
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0275 - val_loss: 0.0339
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0271 - val_loss: 0.0329
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.0267 - val_loss: 0.0320
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - loss: 0.0262 - val_loss: 0.0312
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 0.0258 - val_loss: 0.0304
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0253 - val_loss: 0.0299
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0249 - val_loss: 0.0295
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.0246 - val_loss: 0.0290
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0242 - val_loss: 0.0285
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0238 - val_loss: 0.0281
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0235 - val_loss: 0.0275
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0230 - val_loss: 0.0270
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.0226 - val_loss: 0.0265
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.0222 - val_loss: 0.0260
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.0219 - val_loss: 0.0257
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - loss: 0.0216 - val_loss: 0.0255
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0213 - val_loss: 0.0255
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 0.0210 - val_loss: 0.0254
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0208 - val_loss: 0.0253
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0206 - val_loss: 0.0249
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0204 - val_loss: 0.0244
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0202 - val_loss: 0.0239
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.0200 - val_loss: 0.0234
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - loss: 0.0198 - val_loss: 0.0230
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.0197 - val_loss: 0.0226
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - loss: 0.0195 - val_loss: 0.0223
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - loss: 0.0194 - val_loss: 0.0219
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0192 - val_loss: 0.0216
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0191 - val_loss: 0.0214
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0189 - val_loss: 0.0212
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0188 - val_loss: 0.0211
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0186 - val_loss: 0.0209
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.0185 - val_loss: 0.0208
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0184 - val_loss: 0.0207
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0184 - val_loss: 0.0208
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step - loss: 0.0183 - val_loss: 0.0209
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.0182 - val_loss: 0.0210
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0181 - val_loss: 0.0209
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0180 - val_loss: 0.0208
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.0179 - val_loss: 0.0207
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - loss: 0.0178 - val_loss: 0.0204
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - loss: 0.0177 - val_loss: 0.0202
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step - loss: 0.0176 - val_loss: 0.0201
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0175 - val_loss: 0.0200
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step - loss: 0.0174 - val_loss: 0.0200
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step - loss: 0.0173 - val_loss: 0.0201
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step - loss: 0.0172 - val_loss: 0.0202
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 0.0171 - val_loss: 0.0203
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - loss: 0.0170 - val_loss: 0.0204
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - loss: 0.0169 - val_loss: 0.0204
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.0168 - val_loss: 0.0204
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - loss: 0.0167 - val_loss: 0.0204
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0167 - val_loss: 0.0204
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.0166 - val_loss: 0.0204
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 0.0200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# Test Loss: 0.019997578114271164
# Predictions: [[10445.266]
#  [10816.173]
#  [14688.625]
#  [15034.099]
#  [11464.167]
#  [ 9730.111]]

# %% [markdown]
# LSTM

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Data (same as provided in your example)
data_combined = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915, 4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845, 5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194, 7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567, 11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991, 13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768, 16740, 30080, 27120, 25200, 26480],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216, 11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580, 10080, 12120, 15500, 14220, 16040],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072, 10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960, 5140, 11840, 15680, 14460, 15900]
}

# Preparing the dataset
def create_dataset(data, window_size=3):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

X_p2, y_p2 = create_dataset(data_combined["Tower 2"], window_size=3)

# Scaling data
scaler_X = MinMaxScaler()
X_p2_scaled = scaler_X.fit_transform(X_p2)

y_p2 = y_p2.reshape(-1, 1)
scaler_y = MinMaxScaler()
y_p2_scaled = scaler_y.fit_transform(y_p2)

# Reshaping data for LSTM input
X_p2_scaled = X_p2_scaled.reshape((X_p2_scaled.shape[0], X_p2_scaled.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X_p2_scaled, y_p2_scaled, test_size=0.2, random_state=42)

# Build LSTM model
model = Sequential([
    LSTM(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    LSTM(64, return_sequences=False),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Model training
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])

# Model evaluation
test_loss = model.evaluate(X_test, y_test)

# Making predictions
predictions = model.predict(X_test)
predictions = scaler_y.inverse_transform(predictions)

# Display results
print("Test Loss:", test_loss)
print("Predictions:", predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step - loss: 0.4402 - val_loss: 0.4256
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4078 - val_loss: 0.4054
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - loss: 0.3848 - val_loss: 0.3822
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3591 - val_loss: 0.3576
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.3315 - val_loss: 0.3324
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.3034 - val_loss: 0.3066
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - loss: 0.2746 - val_loss: 0.2804
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.2452 - val_loss: 0.2541
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.2158 - val_loss: 0.2278
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.1864 - val_loss: 0.2020
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.1573 - val_loss: 0.1774
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - loss: 0.1297 - val_loss: 0.1546
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.1042 - val_loss: 0.1347
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0823 - val_loss: 0.1192
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0656 - val_loss: 0.1096
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0561 - val_loss: 0.1073
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.0553 - val_loss: 0.1119
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0630 - val_loss: 0.1205
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0753 - val_loss: 0.1278
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0856 - val_loss: 0.1304
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0895 - val_loss: 0.1279
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0867 - val_loss: 0.1220
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 0.0796 - val_loss: 0.1150
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 0.0709 - val_loss: 0.1087
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0631 - val_loss: 0.1041
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - loss: 0.0574 - val_loss: 0.1016
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0541 - val_loss: 0.1008
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0530 - val_loss: 0.1012
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0534 - val_loss: 0.1024
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0548 - val_loss: 0.1037
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 0.0566 - val_loss: 0.1049
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0582 - val_loss: 0.1058
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0594 - val_loss: 0.1061
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 0.0600 - val_loss: 0.1058
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0600 - val_loss: 0.1050
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0595 - val_loss: 0.1038
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0585 - val_loss: 0.1023
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.1008
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# Test Loss: 0.10075342655181885
# Predictions: [[11980.2  ]
#  [12376.067]
#  [10935.731]
#  [10244.498]
#  [10902.588]
#  [11584.279]]

# %% [markdown]
# GRU

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.callbacks import EarlyStopping

# Data (same as provided in your example)
data_combined = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915, 4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845, 5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194, 7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567, 11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991, 13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768, 16740, 30080, 27120, 25200, 26480],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216, 11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580, 10080, 12120, 15500, 14220, 16040],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072, 10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960, 5140, 11840, 15680, 14460, 15900]
}

# Preparing the dataset
def create_dataset(data, window_size=3):
    X, y = [], []
    for i in range(len(data) - window_size):
        X.append(data[i:i + window_size])
        y.append(data[i + window_size])
    return np.array(X), np.array(y)

X_p2, y_p2 = create_dataset(data_combined["Tower 2"], window_size=3)

# Scaling data
scaler_X = MinMaxScaler()
X_p2_scaled = scaler_X.fit_transform(X_p2)

y_p2 = y_p2.reshape(-1, 1)
scaler_y = MinMaxScaler()
y_p2_scaled = scaler_y.fit_transform(y_p2)

# Reshaping data for GRU input
X_p2_scaled = X_p2_scaled.reshape((X_p2_scaled.shape[0], X_p2_scaled.shape[1], 1))

X_train, X_test, y_train, y_test = train_test_split(X_p2_scaled, y_p2_scaled, test_size=0.2, random_state=42)

# Build GRU model
model = Sequential([
    GRU(128, input_shape=(X_train.shape[1], X_train.shape[2]), return_sequences=True),
    GRU(64, return_sequences=False),
    Dense(32, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mean_squared_error')

# Early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Model training
history = model.fit(X_train, y_train, epochs=100, validation_data=(X_test, y_test), verbose=1, callbacks=[early_stopping])

# Model evaluation
test_loss = model.evaluate(X_test, y_test)

# Making predictions
predictions = model.predict(X_test)
predictions = scaler_y.inverse_transform(predictions)

# Display results
print("Test Loss:", test_loss)
print("Predictions:", predictions)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step - loss: 0.4509 - val_loss: 0.4149
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.3990 - val_loss: 0.3740
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3549 - val_loss: 0.3330
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.3108 - val_loss: 0.2918
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.2665 - val_loss: 0.2506
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.2224 - val_loss: 0.2098
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step - loss: 0.1788 - val_loss: 0.1716
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1382 - val_loss: 0.1378
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.1027 - val_loss: 0.1105
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0747 - val_loss: 0.0922
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 0.0570 - val_loss: 0.0849
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 0.0519 - val_loss: 0.0890
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0595 - val_loss: 0.1002
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.0749 - val_loss: 0.1109
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.0887 - val_loss: 0.1150
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - loss: 0.0942 - val_loss: 0.1121
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 0.0909 - val_loss: 0.1045
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.0819 - val_loss: 0.0957
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0711 - val_loss: 0.0880
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.0616 - val_loss: 0.0829
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0550 - val_loss: 0.0806
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0516 - val_loss: 0.0807
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 0.0511 - val_loss: 0.0824
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step - loss: 0.0524 - val_loss: 0.0847
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0547 - val_loss: 0.0871
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.0571 - val_loss: 0.0889
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - loss: 0.0591 - val_loss: 0.0900
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 0.0604 - val_loss: 0.0901
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 0.0607 - val_loss: 0.0893
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 0.0601 - val_loss: 0.0878
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 0.0588 - val_loss: 0.0858
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0806
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# Test Loss: 0.08064461499452591
# Predictions: [[12199.168]
#  [12456.672]
#  [11843.451]
#  [11174.068]
#  [11251.015]
#  [11711.868]]

# %% [markdown]
# ARIMA

# %%
import numpy as np
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# Data (same as provided in your example)
data_combined = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915, 4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845, 5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194, 7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567, 11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991, 13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768, 16740, 30080, 27120, 25200, 26480],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216, 11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580, 10080, 12120, 15500, 14220, 16040],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072, 10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960, 5140, 11840, 15680, 14460, 15900]
}

# Selecting data for "Tower 2"
data_tower_2 = data_combined["Tower 2"]

# Splitting data into train and test sets (80-20 split)
train_size = int(len(data_tower_2) * 0.8)
train_data, test_data = data_tower_2[:train_size], data_tower_2[train_size:]

# Building ARIMA model
# ARIMA order (p, d, q) - chosen based on initial observation; can be tuned further
model = ARIMA(train_data, order=(3, 1, 2))
model_fit = model.fit()

# Forecasting
forecast = model_fit.forecast(steps=len(test_data))
test_loss = mean_squared_error(test_data, forecast)

# Displaying results
print("Test Loss (MSE):", test_loss)
print("Predictions:", forecast)
print("Actual values:", test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# Test Loss (MSE): 13278681.629766094
# Predictions: [ 9569.46629366  9880.09818557 10513.80750319 10947.90730909
#  11207.37946862 11175.5937623 ]
# Actual values: [9960, 5140, 11840, 15680, 14460, 15900]
# /usr/local/lib/python3.10/dist-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %% [markdown]
# SARIMA

# %%
import numpy as np
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_squared_error

# Data (same as provided in your example)
data_combined = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915, 4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845, 5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194, 7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567, 11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991, 13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768, 16740, 30080, 27120, 25200, 26480],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216, 11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580, 10080, 12120, 15500, 14220, 16040],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072, 10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960, 5140, 11840, 15680, 14460, 15900]
}

# Selecting data for "Tower 2"
data_tower_2 = data_combined["Tower 2"]

# Splitting data into train and test sets (80-20 split)
train_size = int(len(data_tower_2) * 0.8)
train_data, test_data = data_tower_2[:train_size], data_tower_2[train_size:]

# Building SARIMA model
# SARIMA order (p, d, q)(P, D, Q, s) - chosen based on initial observation; can be tuned further
model = SARIMAX(train_data, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
model_fit = model.fit(disp=False)

# Forecasting
forecast = model_fit.forecast(steps=len(test_data))
test_loss = mean_squared_error(test_data, forecast)

# Displaying results
print("Test Loss (MSE):", test_loss)
print("Predictions:", forecast)
print("Actual values:", test_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/statespace/sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# Test Loss (MSE): 24762643.35141922
# Predictions: [ 8714.03663988 12914.98317056 18464.17474987 19350.76838445
#  19427.99460776 18030.2276966 ]
# Actual values: [9960, 5140, 11840, 15680, 14460, 15900]

# %% [markdown]
# Transformer

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

def transformer_encoder(inputs, head_size, num_heads, ff_dim, dropout=0):
    x = layers.LayerNormalization(epsilon=1e-6)(inputs)
    x = layers.MultiHeadAttention(
        key_dim=head_size, num_heads=num_heads, dropout=dropout
    )(x, x)
    x = layers.Dropout(dropout)(x)
    res = x + inputs

    x = layers.LayerNormalization(epsilon=1e-6)(res)
    x = layers.Conv1D(filters=ff_dim, kernel_size=1, activation="relu")(x)
    x = layers.Dropout(dropout)(x)
    x = layers.Conv1D(filters=inputs.shape[-1], kernel_size=1)(x)
    return x + res

def build_transformer_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout=0,
    mlp_dropout=0,
):
    inputs = keras.Input(shape=input_shape)
    x = inputs
    for _ in range(num_transformer_blocks):
        x = transformer_encoder(x, head_size, num_heads, ff_dim, dropout)

    x = layers.GlobalAveragePooling1D()(x)
    for dim in mlp_units:
        x = layers.Dense(dim, activation="relu")(x)
        x = layers.Dropout(mlp_dropout)(x)
    outputs = layers.Dense(1)(x)
    return keras.Model(inputs, outputs)

input_shape = X_train.shape[1:]
head_size = 256
num_heads = 4
ff_dim = 4
num_transformer_blocks = 4
mlp_units = [128]
mlp_dropout = 0.4
dropout = 0.25

model = build_transformer_model(
    input_shape,
    head_size,
    num_heads,
    ff_dim,
    num_transformer_blocks,
    mlp_units,
    dropout,
    mlp_dropout,
)

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss="mean_squared_error",
)

callbacks = [keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True)]
history = model.fit(
    X_train,
    y_train,
    batch_size=32,
    epochs=100,
    validation_split=0.2,
    callbacks=callbacks,
    verbose=1,
)

test_loss = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Loss: {test_loss}")

predictions = model.predict(X_test)
predictions = scaler_y.inverse_transform(predictions)
print("Predictions:", predictions)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 19s 19s/step - loss: 0.6659 - val_loss: 0.5428
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 0.6651 - val_loss: 0.5357
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.6662 - val_loss: 0.5286
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - loss: 0.6016 - val_loss: 0.5217
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.6247 - val_loss: 0.5149
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - loss: 0.6182 - val_loss: 0.5082
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.5899 - val_loss: 0.5016
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.6185 - val_loss: 0.4951
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step - loss: 0.5928 - val_loss: 0.4887
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - loss: 0.5875 - val_loss: 0.4823
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - loss: 0.6320 - val_loss: 0.4760
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.5960 - val_loss: 0.4698
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - loss: 0.5923 - val_loss: 0.4637
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - loss: 0.5738 - val_loss: 0.4576
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - loss: 0.5573 - val_loss: 0.4517
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step - loss: 0.5364 - val_loss: 0.4459
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.5708 - val_loss: 0.4402
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - loss: 0.5405 - val_loss: 0.4345
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.5720 - val_loss: 0.4289
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.5801 - val_loss: 0.4233
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.5183 - val_loss: 0.4180
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.5272 - val_loss: 0.4127
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - loss: 0.5300 - val_loss: 0.4076
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.5369 - val_loss: 0.4025
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 0.5261 - val_loss: 0.3976
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.5041 - val_loss: 0.3927
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - loss: 0.4902 - val_loss: 0.3881
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.4904 - val_loss: 0.3839
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.5007 - val_loss: 0.3809
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.4857 - val_loss: 0.3785
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - loss: 0.4936 - val_loss: 0.3762
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.4781 - val_loss: 0.3734
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4825 - val_loss: 0.3705
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4800 - val_loss: 0.3678
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - loss: 0.4638 - val_loss: 0.3657
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - loss: 0.4613 - val_loss: 0.3634
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.4660 - val_loss: 0.3610
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4926 - val_loss: 0.3589
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.4720 - val_loss: 0.3566
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 152ms/step - loss: 0.4739 - val_loss: 0.3542
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.4557 - val_loss: 0.3518
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.4543 - val_loss: 0.3495
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.4611 - val_loss: 0.3470
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4594 - val_loss: 0.3445
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.4522 - val_loss: 0.3420
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - loss: 0.4454 - val_loss: 0.3395
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - loss: 0.4556 - val_loss: 0.3369
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.4205 - val_loss: 0.3343
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4378 - val_loss: 0.3317
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 0.4484 - val_loss: 0.3291
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 105ms/step - loss: 0.4283 - val_loss: 0.3264
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.4230 - val_loss: 0.3235
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.4243 - val_loss: 0.3206
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.4147 - val_loss: 0.3176
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step - loss: 0.4102 - val_loss: 0.3148
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - loss: 0.4229 - val_loss: 0.3116
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.4046 - val_loss: 0.3083
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.4134 - val_loss: 0.3050
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step - loss: 0.4026 - val_loss: 0.3016
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3935 - val_loss: 0.2984
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.4042 - val_loss: 0.2951
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 0.3907 - val_loss: 0.2919
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.3860 - val_loss: 0.2886
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.3723 - val_loss: 0.2854
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3883 - val_loss: 0.2820
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - loss: 0.3878 - val_loss: 0.2785
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step - loss: 0.3928 - val_loss: 0.2750
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - loss: 0.3463 - val_loss: 0.2714
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - loss: 0.3863 - val_loss: 0.2677
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - loss: 0.3461 - val_loss: 0.2639
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - loss: 0.3394 - val_loss: 0.2601
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - loss: 0.3460 - val_loss: 0.2561
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step - loss: 0.3338 - val_loss: 0.2521
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - loss: 0.3295 - val_loss: 0.2480
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step - loss: 0.3567 - val_loss: 0.2439
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - loss: 0.3447 - val_loss: 0.2397
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - loss: 0.3385 - val_loss: 0.2354
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - loss: 0.3187 - val_loss: 0.2310
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - loss: 0.3106 - val_loss: 0.2266
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step - loss: 0.3231 - val_loss: 0.2221
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step - loss: 0.2595 - val_loss: 0.2175
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - loss: 0.2906 - val_loss: 0.2127
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - loss: 0.3044 - val_loss: 0.2079
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - loss: 0.3169 - val_loss: 0.2031
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - loss: 0.2670 - val_loss: 0.1982
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - loss: 0.2967 - val_loss: 0.1934
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 0.3174 - val_loss: 0.1885
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - loss: 0.2919 - val_loss: 0.1836
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - loss: 0.3268 - val_loss: 0.1787
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - loss: 0.3010 - val_loss: 0.1739
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - loss: 0.2579 - val_loss: 0.1691
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - loss: 0.2363 - val_loss: 0.1641
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - loss: 0.2401 - val_loss: 0.1592
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - loss: 0.2897 - val_loss: 0.1543
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step - loss: 0.2490 - val_loss: 0.1494
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 129ms/step - loss: 0.2596 - val_loss: 0.1446
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step - loss: 0.2448 - val_loss: 0.1397
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - loss: 0.2844 - val_loss: 0.1349
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step - loss: 0.2475 - val_loss: 0.1302
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - loss: 0.1860 - val_loss: 0.1255
# Test Loss: 0.19240951538085938
# WARNING:tensorflow:6 out of the last 6 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x7c3ba0112170> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 819ms/step
# Predictions: [[7914.5225]
#  [7850.6675]
#  [7954.3335]
#  [8131.3135]
#  [8163.675 ]
#  [8062.241 ]]
