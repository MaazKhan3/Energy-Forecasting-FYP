# %%
import numpy as np

months = ["Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

locations = ["P2 Shopping Gallery", "P10 Shopping Gallery", "BTIH", "Tower 1", "Tower 2"]
installed_capacity = [50, 50, 184, 100, 100]

data = {
    "P2 Shopping Gallery": [5606, 6981, 7590, 7975, 6495, 6637, 6637, 4568, 6009, 6902, 5593, 4915],
    "P10 Shopping Gallery": [6240, 7322, 8416, 7639, 5848, 5886, 5886, 4694, 6149, 7102, 5925, 5194],
    "BTIH": [0, 0, 0, 6329, 24543, 18429, 18429, 15822, 22795, 23686, 21234, 19991],
    "Tower 1": [11342, 14562, 16511, 16024, 13508, 12785, 12785, 9205, 13074, 13515, 12221, 11216],
    "Tower 2": [6217, 13976, 15332, 15362, 13406, 12607, 12607, 9005, 12491, 12414, 11078, 10072],
}

fig, ax1 = plt.subplots(figsize=(12, 6))

fig, ax2 = plt.subplots(figsize=(12, 6))

for location in locations:
    ax1.bar(months, data[location], label=location)
    ax2.plot(months, data[location], marker='o', label=location)

ax1.set_title('Monthly Energy Generation by Location (Bar Plot)')
ax1.set_xlabel('Months')
ax1.set_ylabel('Total Generation (kWh)')
ax1.legend(loc="upper left", bbox_to_anchor=(1,1))

ax2.set_title('Monthly Energy Generation by Location (Line Plot)')
ax2.set_xlabel('Months')
ax2.set_ylabel('Total Generation (kWh)')
ax2.legend(loc="upper left", bbox_to_anchor=(1,1))

fig.tight_layout()

plt.show()

# %%
import numpy as np

months = ["Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

locations = ["P2 Shopping Gallery", "P10 Shopping Gallery", "Hospital-1", "Tower 1", "Tower 2"]
installed_capacity = [50, 50, 184, 100, 100]

data = {
    "P2 Shopping Gallery": [4429, 4765, 7167, 7263, 7470, 6476, 5267, 3423, 5670, 5824, 4845, 4845],
    "P10 Shopping Gallery": [7365, 11260, 15286, 16239, 16469, 14010, 10301, 8270, 12587, 12876, 11272, 10567],
    "Hospital-1": [13772, 13478, 25480, 25800, 24240, 21440, 16120, 13400, 20460, 19980, 19000, 18768],
    "Tower 1": [11297, 13077, 14780, 15680, 15040, 13160, 10820, 7920, 12020, 12387, 9580, 9580],
    "Tower 2": [10135, 11770, 13620, 14860, 14120, 12320, 10540, 7960, 11440, 11658, 9960, 9960],
}

fig, ax1 = plt.subplots(figsize=(12, 6))

fig, ax2 = plt.subplots(figsize=(12, 6))

for location in locations:
    ax1.bar(months, data[location], label=location)
    ax2.plot(months, data[location], marker='o', label=location)

ax1.set_title('Monthly Energy Generation by Location (Bar Plot)')
ax1.set_xlabel('Months')
ax1.set_ylabel('Total Generation (kWh)')
ax1.legend(loc="upper left", bbox_to_anchor=(1,1))

ax2.set_title('Monthly Energy Generation by Location (Line Plot)')
ax2.set_xlabel('Months')
ax2.set_ylabel('Total Generation (kWh)')
ax2.legend(loc="upper left", bbox_to_anchor=(1,1))

fig.tight_layout()

plt.show()

# %%
import numpy as np

months = ["Jan", "Feb", "March", "April", "May"]

locations = ["P2 Shopping Gallery", "P10 Shopping Gallery", "Hospital-1", "Tower 1", "Tower 2"]
installed_capacity = [50, 50, 184, 100, 100]

data = {
    "P2 Shopping Gallery": [5270, 5857, 7594, 6902, 7707],
    "P10 Shopping Gallery": [11743, 12330, 14577, 13980, 16939],
    "Hospital-1": [16740, 30080, 27120, 25200, 26480],
    "Tower 1": [10080, 12120, 15500, 14220, 16040],
    "Tower 2": [5140, 11840, 15680, 14460, 15900],
}

fig, ax1 = plt.subplots(figsize=(12, 6))

fig, ax2 = plt.subplots(figsize=(12, 6))

for location in locations:
    ax1.bar(months, data[location], label=location)
    ax2.plot(months, data[location], marker='o', label=location)

ax1.set_title('Monthly Energy Generation by Location (Bar Plot)')
ax1.set_xlabel('Months')
ax1.set_ylabel('Total Generation (kWh)')
ax1.legend(loc="upper left", bbox_to_anchor=(1,1))

ax2.set_title('Monthly Energy Generation by Location (Line Plot)')
ax2.set_xlabel('Months')
ax2.set_ylabel('Total Generation (kWh)')
ax2.legend(loc="upper left", bbox_to_anchor=(1,1))

fig.tight_layout()

plt.show()
